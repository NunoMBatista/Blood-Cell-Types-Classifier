# %%
# !pip install medmnist
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from medmnist) (2.3.3)
# Requirement already satisfied: pandas in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from medmnist) (2.3.2)
# Requirement already satisfied: scikit-learn in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from medmnist) (1.7.2)
# Collecting scikit-image (from medmnist)
#   Downloading scikit_image-0.25.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting tqdm (from medmnist)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: Pillow in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from medmnist) (11.3.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from medmnist) (2.8.0)
# Requirement already satisfied: torchvision in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from medmnist) (0.23.0)
# Collecting termcolor (from fire->medmnist)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from pandas->medmnist) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: scipy>=1.11.4 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from scikit-image->medmnist) (1.16.2)
# Requirement already satisfied: networkx>=3.0 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from scikit-image->medmnist) (3.5)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->medmnist)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->medmnist)
#   Downloading tifffile-2025.10.16-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from scikit-image->medmnist) (25.0)
# Collecting lazy-loader>=0.4 (from scikit-image->medmnist)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib>=1.2.0 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from scikit-learn->medmnist) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from scikit-learn->medmnist) (3.6.0)
# Requirement already satisfied: filelock in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (4.15.0)
# Requirement already satisfied: setuptools in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (1.14.0)
# Requirement already satisfied: jinja2 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (3.1.6)
# Requirement already satisfied: fsspec in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from torch->medmnist) (3.4.0)
# Requirement already satisfied: six>=1.5 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from sympy>=1.13.3->torch->medmnist) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nuno/python_envs/ML/lib/python3.12/site-packages (from jinja2->torch->medmnist) (3.0.2)
# Downloading medmnist-3.0.2-py3-none-any.whl (25 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 6.3 MB/s eta 0:00:00
# Downloading scikit_image-0.25.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 21.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 kB 19.4 MB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2025.10.16-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.2/231.2 kB 19.9 MB/s eta 0:00:00
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: tqdm, tifffile, termcolor, lazy-loader, imageio, scikit-image, fire, medmnist
# Successfully installed fire-0.7.1 imageio-2.37.0 lazy-loader-0.4 medmnist-3.0.2 scikit-image-0.25.2 termcolor-3.1.0 tifffile-2025.10.16 tqdm-4.67.1

# %%
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision.transforms as transforms

import medmnist
from medmnist import INFO, Evaluator

# %%
print(f"MedMNIST v{medmnist.__version__} @ {medmnist.HOMEPAGE}")
# Out:
# MedMNIST v3.0.2 @ https://github.com/MedMNIST/MedMNIST/

# %% [markdown]
# # We work on the 2D dataset with size 28x28

# %%
data_flag = 'bloodmnist'
download = True
BATCH_SIZE = 128

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(medmnist, info['python_class'])

# %% [markdown]
# ## First, we read the MedMNIST data, preprocess them and encapsulate them into dataloader form.

# %%
# preprocessing
data_transform = transforms.Compose([
    transforms.ToTensor(),
])

# load the data
train_dataset = DataClass(split='train', transform=data_transform, download=download)
test_dataset = DataClass(split='test', transform=data_transform, download=download)

pil_dataset = DataClass(split='train', download=download)

# encapsulate data into dataloader form
train_loader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
train_loader_at_eval = data.DataLoader(dataset=train_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
test_loader = data.DataLoader(dataset=test_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
# Out:
# 100%|██████████| 35.5M/35.5M [00:21<00:00, 1.64MB/s]

# %%
print(train_dataset)
print("===================")
print(test_dataset)
# Out:
# Dataset BloodMNIST of size 28 (bloodmnist)
#     Number of datapoints: 11959
#     Root location: /home/nuno/.medmnist
#     Split: train
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'basophil', '1': 'eosinophil', '2': 'erythroblast', '3': 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', '4': 'lymphocyte', '5': 'monocyte', '6': 'neutrophil', '7': 'platelet'}
#     Number of samples: {'train': 11959, 'val': 1712, 'test': 3421}
#     Description: The BloodMNIST is based on a dataset of individual normal cells, captured from individuals without infection, hematologic or oncologic disease and free of any pharmacologic treatment at the moment of blood collection. It contains a total of 17,092 images and is organized into 8 classes. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images with resolution 3×360×363 pixels are center-cropped into 3×200×200, and then resized into 3×28×28.
#     License: CC BY 4.0
# ===================
# Dataset BloodMNIST of size 28 (bloodmnist)
#     Number of datapoints: 3421
#     Root location: /home/nuno/.medmnist
#     Split: test
#     Task: multi-class
#     Number of channels: 3
#     Meaning of labels: {'0': 'basophil', '1': 'eosinophil', '2': 'erythroblast', '3': 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', '4': 'lymphocyte', '5': 'monocyte', '6': 'neutrophil', '7': 'platelet'}
#     Number of samples: {'train': 11959, 'val': 1712, 'test': 3421}
#     Description: The BloodMNIST is based on a dataset of individual normal cells, captured from individuals without infection, hematologic or oncologic disease and free of any pharmacologic treatment at the moment of blood collection. It contains a total of 17,092 images and is organized into 8 classes. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images with resolution 3×360×363 pixels are center-cropped into 3×200×200, and then resized into 3×28×28.
#     License: CC BY 4.0

# %%
# visualization

train_dataset.montage(length=1)
# Out:
# <PIL.Image.Image image mode=RGB size=28x28>

# %%
# montage

train_dataset.montage(length=15)
# Out:
# <PIL.Image.Image image mode=RGB size=420x420>
